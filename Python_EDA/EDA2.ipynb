# %% [markdown]
# # IMPORT LIBRARIES

# %%
import json 
from pathlib import Path

import pandas as pd
import numpy as np
import networkx as nx

# %% [markdown]
# # DATA LOADING

# %%
links = pd.read_parquet("data_clean/links.parquet")
vessels = pd.read_parquet("data_clean/vessels.parquet")
locations = pd.read_parquet("data_clean/locations.parquet")
deliveries = pd.read_parquet("data_clean/deliveries.parquet")
fish = pd.read_parquet("data_clean/fish.parquet")

# %% [markdown]
# # INSPECTION

# %%
vessels.columns
# Out:
# Index(['vessel_id', 'company', 'flag_country', 'length_overall', 'tonnage'], dtype='object')

# %%
fish.columns
# Out:
# Index(['id', 'entity_name'], dtype='object')

# %%
deliveries.columns
# Out:
# Index(['delivery_cargo_id', 'date', 'qty_tons'], dtype='object')

# %%
locations.columns
# Out:
# Index(['location_id', 'Activities', 'fish_species_present', 'kind'], dtype='object')

# %%
links.columns
# Out:
# Index(['type', 'time', 'dwell', 'source', 'target', 'key', 'main_type',
#        'week'],
#       dtype='object')

# %%
vessels = vessels[["vessel_id", "company", "flag_country", "length_overall", "tonnage"]]
locations = locations[["location_id", "Activities", "fish_species_present", "kind"]]
fish = fish[["id","entity_name" ]]
deliveries = deliveries[["delivery_cargo_id", "date", "qty_tons"]]
links = links[["source", "target", "main_type", "time", "dwell", "week"]]

# %%
ping   = links[links["main_type"] == "TransportEvent"].copy()
harbor = links[links["main_type"] == "HarborReport"].copy()
trans  = links[links["main_type"] == "Transaction"].copy()

# %% [markdown]
# # Merge

# %%
vessels
# Out:
#                    vessel_id                  company flag_country  \
# 0            wavewranglerc2d   Roth, Logan and Moreno      Oceanus
# 1      yellowfintunataker08b               Brown-Haas      Oceanus
# 2    arcticgraylingangler094  Smith, Davis and Acosta      Oceanus
# 3        anchovyassaulterb1c           Cisneros-Meyer      Oceanus
# 4             oceanreaper44a  FlounderLeska Marine BV      Oceanus
# ..                       ...                      ...          ...
# 273        seawayspectrumca2                  Unknown     Kethanor
# 274     oceanicomnipotenta4a                  Unknown  Playa Solis
# 275            seawaysage5ce                  Unknown     Coralada
# 276     nauticalnucleus107c4                  Unknown    Zawalinda
# 277     maritimemagnitude2e9                  Unknown    Gavanovia
#
#      length_overall  tonnage
# 0             110.0    700.0
# 1             110.0   4500.0
# 2              80.0   1500.0
# 3              60.0    400.0
# 4              50.0    300.0
# ..              ...      ...
# 273           100.0   2600.0
# 274           210.0  76300.0
# 275           100.0   2100.0
# 276           100.0   2100.0
# 277            90.0   2100.0
#
# [278 rows x 5 columns]

# %%
locations
# Out:
#                 location_id  \
# 0          City of Haacklee
# 1            City of Lomark
# 2            City of Himark
# 3         City of Paackland
# 4   City of South Paackland
# 5        City of Port Grove
# 6                 Exit West
# 7                     Nav 3
# 8                     Nav D
# 9                     Nav B
# 10                    Nav A
# 11                    Nav C
# 12                    Nav 2
# 13                    Nav 1
# 14                Exit East
# 15               Exit South
# 16               Exit North
# 17                    Nav E
# 18                Cod Table
# 19           Ghoti Preserve
# 20              Wrasse Beds
# 21                Nemo Reef
# 22      Don Limpet Preserve
# 23               Tuna Shelf
#
#                                            Activities  \
# 0                             Tourism, Local shipping
# 1   Deep sea fishing, Commercial fishing, Tourism,...
# 2                                 Recreation, tourism
# 3   Industry, Fishing industry, Local shipping, To...
# 4          Industry, Fishing industry, Local shipping
# 5                                   Tourism, Research
# 6            International shipping, Deep sea fishing
# 7                                          Navigation
# 8                                          Navigation
# 9                                          Navigation
# 10                                         Navigation
# 11                                         Navigation
# 12                                         Navigation
# 13                                         Navigation
# 14           International shipping, Deep sea fishing
# 15           International shipping, Deep sea fishing
# 16           International shipping, Deep sea fishing
# 17                                         Navigation
# 18                                 Commercial fishing
# 19                      Research, Tourism, Recreation
# 20                                 Commercial fishing
# 21                                Recreation, Tourism
# 22                                Recreation, Tourism
# 23                  Commercial fishing, Sport fishing
#
#                                  fish_species_present                 kind
# 0                                             Unknown                 city
# 1                                             Unknown                 city
# 2                                             Unknown                 city
# 3                                             Unknown                 city
# 4                                             Unknown                 city
# 5                                             Unknown                 city
# 6                                             Unknown                 buoy
# 7                                             Unknown                 buoy
# 8                                             Unknown                 buoy
# 9                                             Unknown                 buoy
# 10                                            Unknown                 buoy
# 11                                            Unknown                 buoy
# 12                                            Unknown                 buoy
# 13                                            Unknown                 buoy
# 14                                            Unknown                 buoy
# 15                                            Unknown                 buoy
# 16                                            Unknown                 buoy
# 17                                            Unknown                 buoy
# 18  Cod/Gadus n.specificatae, Birdseye/Pisces frig...       Fishing Ground
# 19  Wrasse/Labridae n.refert, Beauvoir/Habeas pisc...  Ecological Preserve
# 20  Wrasse/Labridae n.refert, Birdseye/Pisces frig...       Fishing Ground
# 21  Wrasse/Labridae n.refert, Tuna/Thunnini n.vera...  Ecological Preserve
# 22  Tuna/Thunnini n.vera, Birdseye/Pisces frigus, ...  Ecological Preserve
# 23  Tuna/Thunnini n.vera, Birdseye/Pisces frigus, ...       Fishing Ground

# %%
harbor
# Out:
#                       source                   target     main_type  \
# 32062        wavewranglerc2d         City of Haacklee  HarborReport
# 32063        wavewranglerc2d           City of Himark  HarborReport
# 32064        wavewranglerc2d           City of Lomark  HarborReport
# 32065        wavewranglerc2d  City of South Paackland  HarborReport
# 32066  yellowfintunataker08b         City of Haacklee  HarborReport
# ...                      ...                      ...           ...
# 34933   nauticalnucleus107c4         City of Haacklee  HarborReport
# 34934   maritimemagnitude2e9           City of Himark  HarborReport
# 34935   maritimemagnitude2e9  City of South Paackland  HarborReport
# 34936   maritimemagnitude2e9           City of Lomark  HarborReport
# 34937   maritimemagnitude2e9         City of Haacklee  HarborReport
#
#             time  dwell  week
# 32062 2035-09-14    0.0    37
# 32063 2035-08-16    0.0    33
# 32064 2035-04-07    0.0    14
# 32065 2035-07-05    0.0    27
# 32066 2035-09-03    0.0    36
# ...          ...    ...   ...
# 34933 2035-11-01    0.0    44
# 34934 2035-02-28    0.0     9
# 34935 2035-08-05    0.0    31
# 34936 2035-04-07    0.0    14
# 34937 2035-07-24    0.0    30
#
# [894 rows x 6 columns]

# %%
len(set(vessels["vessel_id"]) & set(harbor["source"]))
# Out:
# 278

# %%
mistakes = []
for sources in harbor["source"].unique():
    if sources not in set(vessels["vessel_id"]):
        mistakes.append(sources)

# %%
mistakes
# Out:
# ['webigailba7',
#  'venerable89c',
#  'sturdyd7f',
#  'stout369',
#  'inquisitive8c0',
#  'dewie961',
#  'himarkroyal032',
#  'mrray9c4',
#  'manatee17ea',
#  'hewey2ef',
#  'honorablea6e',
#  'clownfishe3d',
#  'louietheii3e0',
#  'respectable717',
#  'spiritofoceanus404',
#  'louieda4',
#  'athenad34',
#  'heartofoceanusf11']

# %%
vessels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vessel_id       278 non-null    object
#  1   company         278 non-null    object
#  2   flag_country    278 non-null    object
#  3   length_overall  278 non-null    float64
#  4   tonnage         278 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 11.0+ KB

# %%
harbor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 894 entries, 32062 to 34937
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source     894 non-null    object
#  1   target     894 non-null    object
#  2   main_type  894 non-null    object
#  3   time       894 non-null    datetime64[ns]
#  4   dwell      894 non-null    float64
#  5   week       894 non-null    UInt32
# dtypes: UInt32(1), datetime64[ns](1), float64(1), object(3)
# memory usage: 46.3+ KB

# %%
vessels[vessels["vessel_id"] == "venerable89c"]
# Out:
# Empty DataFrame
# Columns: [vessel_id, company, flag_country, length_overall, tonnage]
# Index: []

# %%
# Porto = source, Nave = target
harbor = harbor.merge(vessels, left_on="source", right_on="vessel_id", how="left")
harbor = harbor.merge(locations, left_on="target", right_on="location_id", how="left")

# %%
harbor.dropna(axis=0, how='any', inplace=True)

# %%
harbor = harbor[[
    "source", "target", "time", "week",
    "company", "flag_country", "length_overall", "tonnage",
    "Activities", "fish_species_present", "kind"
]]

# %%
# cargo → harbor
trans_harbor = trans[trans["target"].isin(locations["location_id"])].copy()

# cargo → fish
trans_fish = trans[trans["target"].isin(fish["id"])].copy()

print("Cargo→Harbor:", len(trans_harbor))
print("Cargo→Fish:", len(trans_fish))
# Out:
# Cargo→Harbor: 5307
# Cargo→Fish: 5307

# %%
# Merge sui cargo_id comuni
trans = trans_harbor.merge(
    trans_fish,
    on="source",  # cargo_2035_...
    suffixes=("_harbor", "_fish")
)

print("Record combinati (cargo→harbor→fish):", len(trans))
# Out:
# Record combinati (cargo→harbor→fish): 5307

# %%
trans.head()
# Out:
#                 source            target_harbor main_type_harbor time_harbor  \
# 0  cargo_2035_2394778c  City of South Paackland      Transaction  2035-11-03
# 1  cargo_2035_23956ba0  City of South Paackland      Transaction  2035-08-16
# 2  cargo_2035_23957cfd  City of South Paackland      Transaction  2035-08-20
# 3  cargo_2035_23958501        City of Paackland      Transaction  2035-11-07
# 4  cargo_2035_23959ab6  City of South Paackland      Transaction  2035-08-24
#
#    dwell_harbor  week_harbor            target_fish main_type_fish  time_fish  \
# 0           0.0           44  gadusnspecificatae4ba    Transaction 2035-11-03
# 1           0.0           33  gadusnspecificatae4ba    Transaction 2035-08-16
# 2           0.0           34  gadusnspecificatae4ba    Transaction 2035-08-20
# 3           0.0           45  gadusnspecificatae4ba    Transaction 2035-11-07
# 4           0.0           34  gadusnspecificatae4ba    Transaction 2035-08-24
#
#    dwell_fish  week_fish
# 0         0.0         44
# 1         0.0         33
# 2         0.0         34
# 3         0.0         45
# 4         0.0         34

# %%
# Porto (harbor)
locations_ = locations.rename(columns={
    "location_id": "harbor_id",
    "Activities": "Activities_harbor",
    "fish_species_present": "fish_species_harbor",
    "kind": "kind_harbor"
})

# Pesce
fish_ = fish.rename(columns={
    "id": "fish_id",
    "name": "fish_name"
}) if "name" in fish.columns else fish.rename(columns={"id": "fish_id"})

# Merge con i dettagli
trans = (
    trans.merge(locations_, left_on="target_harbor", right_on="harbor_id", how="left")
         .merge(fish_, left_on="target_fish", right_on="fish_id", how="left")
)

# %%
trans
# Out:
#                    source            target_harbor main_type_harbor  \
# 0     cargo_2035_2394778c  City of South Paackland      Transaction
# 1     cargo_2035_23956ba0  City of South Paackland      Transaction
# 2     cargo_2035_23957cfd  City of South Paackland      Transaction
# 3     cargo_2035_23958501        City of Paackland      Transaction
# 4     cargo_2035_23959ab6  City of South Paackland      Transaction
# ...                   ...                      ...              ...
# 5302  cargo_2035_3119010f        City of Paackland      Transaction
# 5303  cargo_2035_3119118e        City of Paackland      Transaction
# 5304  cargo_2035_3119237c        City of Paackland      Transaction
# 5305  cargo_2035_311936c4        City of Paackland      Transaction
# 5306  cargo_2035_31194d62        City of Paackland      Transaction
#
#      time_harbor  dwell_harbor  week_harbor            target_fish  \
# 0     2035-11-03           0.0           44  gadusnspecificatae4ba
# 1     2035-08-16           0.0           33  gadusnspecificatae4ba
# 2     2035-08-20           0.0           34  gadusnspecificatae4ba
# 3     2035-11-07           0.0           45  gadusnspecificatae4ba
# 4     2035-08-24           0.0           34  gadusnspecificatae4ba
# ...          ...           ...          ...                    ...
# 5302  2035-08-24           0.0           34        habeaspisces4eb
# 5303  2035-08-25           0.0           34        habeaspisces4eb
# 5304  2035-08-28           0.0           35        habeaspisces4eb
# 5305  2035-08-30           0.0           35        habeaspisces4eb
# 5306  2035-09-01           0.0           35        habeaspisces4eb
#
#      main_type_fish  time_fish  dwell_fish  week_fish  \
# 0       Transaction 2035-11-03         0.0         44
# 1       Transaction 2035-08-16         0.0         33
# 2       Transaction 2035-08-20         0.0         34
# 3       Transaction 2035-11-07         0.0         45
# 4       Transaction 2035-08-24         0.0         34
# ...             ...        ...         ...        ...
# 5302    Transaction 2035-08-24         0.0         34
# 5303    Transaction 2035-08-25         0.0         34
# 5304    Transaction 2035-08-28         0.0         35
# 5305    Transaction 2035-08-30         0.0         35
# 5306    Transaction 2035-09-01         0.0         35
#
#                     harbor_id  \
# 0     City of South Paackland
# 1     City of South Paackland
# 2     City of South Paackland
# 3           City of Paackland
# 4     City of South Paackland
# ...                       ...
# 5302        City of Paackland
# 5303        City of Paackland
# 5304        City of Paackland
# 5305        City of Paackland
# 5306        City of Paackland
#
#                                       Activities_harbor fish_species_harbor  \
# 0            Industry, Fishing industry, Local shipping             Unknown
# 1            Industry, Fishing industry, Local shipping             Unknown
# 2            Industry, Fishing industry, Local shipping             Unknown
# 3     Industry, Fishing industry, Local shipping, To...             Unknown
# 4            Industry, Fishing industry, Local shipping             Unknown
# ...                                                 ...                 ...
# 5302  Industry, Fishing industry, Local shipping, To...             Unknown
# 5303  Industry, Fishing industry, Local shipping, To...             Unknown
# 5304  Industry, Fishing industry, Local shipping, To...             Unknown
# 5305  Industry, Fishing industry, Local shipping, To...             Unknown
# 5306  Industry, Fishing industry, Local shipping, To...             Unknown
#
#      kind_harbor                fish_id               entity_name
# 0           city  gadusnspecificatae4ba  Cod/Gadus n.specificatae
# 1           city  gadusnspecificatae4ba  Cod/Gadus n.specificatae
# 2           city  gadusnspecificatae4ba  Cod/Gadus n.specificatae
# 3           city  gadusnspecificatae4ba  Cod/Gadus n.specificatae
# 4           city  gadusnspecificatae4ba  Cod/Gadus n.specificatae
# ...          ...                    ...                       ...
# 5302        city        habeaspisces4eb    Beauvoir/Habeas pisces
# 5303        city        habeaspisces4eb    Beauvoir/Habeas pisces
# 5304        city        habeaspisces4eb    Beauvoir/Habeas pisces
# 5305        city        habeaspisces4eb    Beauvoir/Habeas pisces
# 5306        city        habeaspisces4eb    Beauvoir/Habeas pisces
#
# [5307 rows x 17 columns]

# %%
trans = trans[[
    "source",                  # cargo id
    "target_harbor",           # porto
    "target_fish",             # specie
    "Activities_harbor", "fish_species_harbor", "kind_harbor", "time_harbor",
    "fish_id"
]]

# %%
deliveries
# Out:
#         delivery_cargo_id       date  qty_tons
# 0     cargo_2035_2394778c 2035-11-03    24.375
# 1     cargo_2035_23956ba0 2035-08-16    18.125
# 2     cargo_2035_23957cfd 2035-08-20    20.625
# 3     cargo_2035_23958501 2035-11-07    13.125
# 4     cargo_2035_23959ab6 2035-08-24    13.125
# ...                   ...        ...       ...
# 4987  cargo_2035_31187527 2035-08-21     7.500
# 4988  cargo_2035_3119010f 2035-08-24    10.000
# 4989  cargo_2035_3119118e 2035-08-25    15.000
# 4990  cargo_2035_311936c4 2035-08-30    19.000
# 4991  cargo_2035_31194d62 2035-09-01     9.500
#
# [4992 rows x 3 columns]

# %%
trans = trans.merge(deliveries, left_on="source", right_on="delivery_cargo_id", how="left")

# %%
cols = [
    "source",
    "target_harbor",
    "Activities_harbor",
    "fish_species_harbor",
    "kind_harbor",
    "fish_id",
    "date",
    "qty_tons",
]
trans = trans[cols]

# %%
trans.dropna(axis=0, inplace=True)

# %%
vessels = vessels.rename(columns={"id": "vessel_id"})
locations = locations.rename(columns={"id": "location_id"})

ping = ping.dropna(subset=["time"]).reset_index(drop=True)

ping = ping.merge(locations, left_on="source", right_on="location_id", how="left")
ping = ping.merge(vessels, left_on="target", right_on="vessel_id", how="left")

ping = ping[[
    "source", "target", "time", "dwell", "week",
    "company", "flag_country", "length_overall", "tonnage",
    "Activities", "fish_species_present", "kind"
]]

# %%
ping.dropna(inplace=True)

# %%
for i in [ping, trans, harbor]:
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 218477 entries, 0 to 240709
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   source                218477 non-null  object
#  1   target                218477 non-null  object
#  2   time                  218477 non-null  datetime64[ns]
#  3   dwell                 218477 non-null  float64
#  4   week                  218477 non-null  UInt32
#  5   company               218477 non-null  object
#  6   flag_country          218477 non-null  object
#  7   length_overall        218477 non-null  float64
#  8   tonnage               218477 non-null  float64
#  9   Activities            218477 non-null  object
#  10  fish_species_present  218477 non-null  object
#  11  kind                  218477 non-null  object
# dtypes: UInt32(1), datetime64[ns](1), float64(3), object(7)
# memory usage: 21.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 4992 entries, 0 to 5306
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   source               4992 non-null   object
#  1   target_harbor        4992 non-null   object
#  2   Activities_harbor    4992 non-null   object
#  3   fish_species_harbor  4992 non-null   object
#  4   kind_harbor          4992 non-null   object
#  5   fish_id              4992 non-null   object
#  6   date                 4992 non-null   datetime64[ns]
#  7   qty_tons             4992 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 351.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 862 entries, 0 to 893
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   source                862 non-null    object
#  1   target                862 non-null    object
#  2   time                  862 non-null    datetime64[ns]
#  3   week                  862 non-null    UInt32
#  4   company               862 non-null    object
#  5   flag_country          862 non-null    object
#  6   length_overall        862 non-null    float64
#  7   tonnage               862 non-null    float64
#  8   Activities            862 non-null    object
#  9   fish_species_present  862 non-null    object
#  10  kind                  862 non-null    object
# dtypes: UInt32(1), datetime64[ns](1), float64(2), object(7)
# memory usage: 78.3+ KB
# None

# %%
fish.to_parquet("data_clean/fish.parquet", index=False, engine='fastparquet')
vessels.to_parquet("data_clean/vessels.parquet", index=False, engine='fastparquet')
locations.to_parquet("data_clean/locations.parquet", index=False, engine='fastparquet')
deliveries.to_parquet("data_clean/deliveries.parquet", index=False, engine='fastparquet')

# %%
ping.to_parquet("data_clean/pings.parquet", index=False, engine='fastparquet')
harbor.to_parquet("data_clean/harbors.parquet", index=False, engine='fastparquet')
trans.to_parquet("data_clean/transactions.parquet", index=False, engine='fastparquet')
